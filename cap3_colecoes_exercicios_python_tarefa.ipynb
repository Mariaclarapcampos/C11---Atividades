# %% [markdown]
# # EXERCÍCIOS DE PYTHON
#
# Este notebook contém exercícios de programação em Python focados em listas, conjuntos e dicionários.

# %% [markdown]
# ## Exercício 1
#
# Crie uma lista preenchida com os 5 primeiros colocados de um Campeonato de Futebol, na ordem de colocação. Depois mostre:
#
# a. Apenas os 3 primeiros colocados;
#
# b. Os últimos 2 colocados;
#
# c. Uma lista com os times em ordem alfabética;
#
# d. Em que posição da tabela se encontra o Barcelona;

# %%
from selectors import SelectSelector

# Exercício 1

# Lista com os 5 primeiros colocados
colocacao = ['Barcelona', 'Real Madrid', 'Paris Saint-Germain', 'Bayern Munich', 'Manchester United']

# a. Apenas os 3 primeiros colocados
print('Os 3 primeirso são: ',colocacao[0:3])

# b. Os últimos 2 colocados
print('Os 2 últimos são: ',colocacao[3:5])

# c. Uma lista com os times em ordem alfabética
print('Em ordem alfabética: ',sorted(colocacao))

# d. Em que posição da tabela se encontra o Barcelona
print('O Barcelona se encontra na posição: ',colocacao.index('Barcelona')+1) #começa a contar em 0
# Out:
# Os 3 primeirso são:  ['Barcelona', 'Real Madrid', 'Paris Saint-Germain']
# Os 2 últimos são:  ['Bayern Munich', 'Manchester United']
# Em ordem alfabética:  ['Barcelona', 'Bayern Munich', 'Manchester United', 'Paris Saint-Germain', 'Real Madrid']
# O Barcelona se encontra na posição:  1

# %% [markdown]
# ## Exercício 2
#
# Crie dois conjuntos, um para cada loja. Identifique quais modelos de smartphones cada uma delas vendem. Em seguida, mostre quais modelos no total você terá opção de comprar se visita-las e quais modelos se encontram disponíveis em ambas as lojas;

# %%
# Exercício 2

# Conjunto de modelos da loja 1
loja1 = {'Apple', 'Samsung', 'Xiaomi', 'Motorola'}

# Conjunto de modelos da loja 2
loja2 = {'Apple', 'Samsung', 'OnePlus', 'Vivo'}

# Modelos disponíveis no total (união)
total = loja1 | loja2
print('As marcas disponiveis são :',total)

# Modelos disponíveis em ambas as lojas (interseção)
ambas = loja1 & loja2
print('As marcas disponíveis em abas as lojas são: ', ambas)
# Out:
# As marcas disponiveis são : {'Samsung', 'Motorola', 'Xiaomi', 'OnePlus', 'Apple', 'Vivo'}
# As marcas disponíveis em abas as lojas são:  {'Samsung', 'Apple'}

# %% [markdown]
# ## Exercício 3
#
# Faça um programa que leia o nome e a média de um aluno e guarde-os em um dicionário. Em seguida, a partir da média (para ser aprovado deve ter média >=50), gere a situação final do aluno ('AP' ou 'RP'), que também deve ser guardada neste dicionário. No final, mostre todo o conteúdo deste dicionário;

# %%
# Exercício 3

# Dicionário do aluno
aluno = [{
    'nome': 'Maria Clara' ,
    'media': 90
    },
    {
        'nome': 'Lorena' ,
        'media': 20
    },
    {
        'nome': 'Nicholas' ,
        'media': 50
    }
]
# Leitura do nome
for alunos in aluno:
    print(alunos['nome'])

# Leitura da média
for nota in aluno:
    print(nota['media'])

# Determinar a situação final
for nota in aluno:
    if nota['media'] >= 50:
        nota['final'] = 'AP'
    else:
        nota['final'] = 'RP'

# Mostrar todo o conteúdo do dicionário
print(aluno)
# Out:
# Maria Clara
# Lorena
# Nicholas
# 90
# 20
# 50
# [{'nome': 'Maria Clara', 'media': 90, 'final': 'AP'}, {'nome': 'Lorena', 'media': 20, 'final': 'RP'}, {'nome': 'Nicholas', 'media': 50, 'final': 'AP'}]

# %% [markdown]
# ## Exercício 4
#
# Faça um programa que leia o nome e peso de 3 pessoas e no final mostre o nome da pessoa mais pesada e a mais leve;

# %%
# Exercício 4

# Lista para armazenar as pessoas
pessoa = [{
        'nome': 'Maria Clara' ,
        'peso': 60
    },
    {
        'nome': 'Lorena' ,
        'peso': 75
    },
    {
        'nome': 'Nicholas' ,
        'peso': 89
    }
]

# Ler dados de 3 pessoas
print(pessoa)

# Encontrar a pessoa mais pesada
mais_pesada = pessoa[0]

for pesada in pessoa:
    if pesada['peso'] > mais_pesada['peso']:
        mais_pesada = pesada
    else:
        mais_pesada =  mais_pesada

# Encontrar a pessoa mais leve
mais_leve = pessoa[0]

for leve in pessoa:
    if pesada['peso'] < mais_leve['peso']:
        mais_leve = leve
    else:
        mais_leve =  mais_leve

# Mostrar os resultados
print('Pessoa mais pesada: ',mais_pesada['nome'], '-', mais_pesada['peso'], 'kg')
print('Pessoa mais leve: ',mais_leve['nome'], '-', mais_leve['peso'], 'kg')
# Out:
# [{'nome': 'Maria Clara', 'peso': 60}, {'nome': 'Lorena', 'peso': 75}, {'nome': 'Nicholas', 'peso': 89}]
# Pessoa mais pesada:  Nicholas - 89 kg
# Pessoa mais leve:  Maria Clara - 60 kg

# %% [markdown]
# ## Exercício 5
#
# Desenvolva um programa que leia o nome, idade e sexo de n pessoas. No final, mostre:
#
# a. A média de idade do grupo;
#
# b. Quantas mulheres têm menos de 20 anos.
#
# **Dica:** em Python, os operadores booleanos básicos são `and`, `or` e `not`.

# %%
# Exercício 5

# Lista para armazenar as pessoas
pessoas = [{
        'nome': 'Maria Clara' ,
        'idade': 20,
        'sexo': 'F'
    },
    {
        'nome': 'Luisa' ,
        'idade': 10,
        'sexo': 'F'
    },
    {
        'nome': 'Julia' ,
        'idade': 12,
        'sexo': 'F'
    },
    {
        'nome': 'Lorena' ,
        'idade': 25,
        'sexo': 'F'
    },
    {
        'nome': 'Nicholas' ,
        'idade': 89,
        'sexo': 'M'
    },
    {
        'nome': 'Michael' ,
        'idade': 29,
        'sexo': 'M'
    }
]
# Número de pessoas
len(pessoas)

# Ler dados das pessoas
print(pessoas)

# a. Calcular a média de idade do grupo
media = 0
for i in pessoas:
    media =+ i['idade']

# b. Contar quantas mulheres têm menos de 20 anos
menor = 0
for m in pessoas:
   if m['sexo'] == 'F' and m['idade'] < 20:
        menor += 1

# Mostrar os resultados
print('Participaram', len(pessoas), ' pessoas')
print('A idade média do grupo é:', media)
print(menor, ' mulheres tem menos que 20 anos')
# Out:
# [{'nome': 'Maria Clara', 'idade': 20, 'sexo': 'F'}, {'nome': 'Luisa', 'idade': 10, 'sexo': 'F'}, {'nome': 'Julia', 'idade': 12, 'sexo': 'F'}, {'nome': 'Lorena', 'idade': 25, 'sexo': 'F'}, {'nome': 'Nicholas', 'idade': 89, 'sexo': 'M'}, {'nome': 'Michael', 'idade': 29, 'sexo': 'M'}]
# Participaram 6  pessoas
# A idade média do grupo é: 29
# 2  mulheres tem menos que 20 anos

# %% [markdown]
# ## Exercício 6: Análise de Vendas - Projeto de Ciência de Dados
#
# Você recebeu um dataset de vendas de uma loja online e precisa realizar uma análise completa dos dados. O dataset contém problemas de qualidade que precisam ser tratados.
# **OBJETIVO:** Limpar o dataset e extrair insights valiosos sobre vendas, clientes, produtos e regiões usando apenas coleções Python!
#
# Seja criativo e capture informaçÕes que você achar relevante!
#
# ### DICAS PARA O EXERCÍCIO:
#
# **Limpeza de Dados:**
# - Você pode usar `.strip()` para remover espaços extras e `.title()` para padronizar capitalização
# - Você pode usar `abs()` para converter valores negativos ou simplesmente remover registros inválidos (valor/quantidade ≤ 0)
# - Você pode criar um dicionário de mapeamento para unificar variações de categorias (ex: `'eletronicos' → 'Eletrônicos'`)
# - Você pode trabalhar com cópias (`.copy()`) para preservar o dataset original
#
# **Análises Possíveis:**
# - Você pode usar **sets** para identificar valores únicos (clientes, produtos, regiões distintas)
# - Você pode usar **dicionários** para agrupar e agregar dados (vendas por categoria, por região, por cliente)
# - Você pode usar `sum()` e `len()` para calcular totais e contar elementos
# - Você pode usar `max()` e `min()` com `key=lambda` para encontrar extremos (maior venda, melhor cliente)
# - Você pode usar `sorted()` com `reverse=True` para criar rankings
# - Você pode usar operações de conjuntos como `&` (interseção) e `|` (união) para análises comparativas

# %%
# Dataset original
vendas = [
    {'id': 1, 'produto': 'Notebook', 'categoria': 'Eletrônicos', 'valor': 3500, 'quantidade': 2, 'regiao': 'Sudeste', 'cliente': 'João Silva'},
    {'id': 2, 'produto': 'Mouse', 'categoria': 'eletronicos', 'valor': 45, 'quantidade': 5, 'regiao': 'sul', 'cliente': 'Maria Santos'},
    {'id': 3, 'produto': 'Teclado', 'categoria': 'Eletrônicos', 'valor': 120, 'quantidade': 3, 'regiao': 'Sudeste', 'cliente': 'joão silva'},
    {'id': 4, 'produto': 'Cadeira Gamer', 'categoria': 'Móveis', 'valor': 890, 'quantidade': 1, 'regiao': 'Norte', 'cliente': 'Pedro Costa'},
    {'id': 5, 'produto': 'Mesa', 'categoria': 'moveis', 'valor': 450, 'quantidade': 2, 'regiao': 'Sul', 'cliente': 'Ana Lima'},
    {'id': 6, 'produto': 'Monitor', 'categoria': 'Eletrônicos', 'valor': 850, 'quantidade': 2, 'regiao': 'Sudeste', 'cliente': 'Carlos Mendes'},
    {'id': 7, 'produto': 'Webcam', 'categoria': 'Eletrônicos', 'valor': -250, 'quantidade': 4, 'regiao': 'Norte', 'cliente': 'Pedro Costa'},
    {'id': 8, 'produto': 'Cadeira Escritório', 'categoria': 'Móveis', 'valor': 350, 'quantidade': 3, 'regiao': 'Sudeste', 'cliente': 'JOAO SILVA'},
    {'id': 9, 'produto': 'Headset', 'categoria': 'eletronicos', 'valor': 180, 'quantidade': 0, 'regiao': 'Sul', 'cliente': 'Maria Santos'},
    {'id': 10, 'produto': 'SSD', 'categoria': 'Eletrônicos', 'valor': 380, 'quantidade': 3, 'regiao': 'norte', 'cliente': 'Fernanda Rocha'},
    {'id': 11, 'produto': '  Mouse Gamer  ', 'categoria': 'Eletrônicos', 'valor': 150, 'quantidade': 2, 'regiao': '  Sudeste  ', 'cliente': 'João Silva'},
    {'id': 12, 'produto': 'Teclado Mecânico', 'categoria': 'Eletronicos', 'valor': 0, 'quantidade': 1, 'regiao': 'Sul', 'cliente': 'maria santos'},
]

print('='*70)
print('ANÁLISE DE VENDAS - PROJETO DE CIÊNCIA DE DADOS')
print('='*70)
print(f'\nDataset original: {len(vendas)} registros')

#limpeza de dados
vendas_limpa = []

mapa_categoria = {
    'eletronicos': 'Eletrônicos',
    'eletrônicos': 'Eletrônicos',
    'eletronicos': 'Eletrônicos',
    'moveis': 'Móveis',
    'móveis': 'Móveis'
}

for v in vendas:

    venda = v.copy()

    # limpar textos
    venda['produto'] = venda['produto'].strip().title()
    venda['cliente'] = venda['cliente'].strip().title()
    venda['regiao'] = venda['regiao'].strip().title()

    cat = venda['categoria'].strip().lower()
    venda['categoria'] = mapa_categoria.get(cat, cat.title())

    # remover registros inválidos
    if venda['valor'] <= 0 or venda['quantidade'] <= 0:
        continue

    vendas_limpa.append(venda)

print(f'Dataset limpo: {len(vendas_limpa)} registros')

# análises

clientes = set()
regioes = set()
produtos = set()

vendas_categoria = {}
vendas_regiao = {}
gasto_cliente = {}
quantidade_produto = {}

faturamento_total = 0

for v in vendas_limpa:

    total = v['valor'] * v['quantidade']
    faturamento_total += total

    clientes.add(v['cliente'])
    regioes.add(v['regiao'])
    produtos.add(v['produto'])

    # vendas por categoria
    cat = v['categoria']
    vendas_categoria[cat] = vendas_categoria.get(cat, 0) + total

    # vendas por região
    reg = v['regiao']
    vendas_regiao[reg] = vendas_regiao.get(reg, 0) + total

    # gasto por cliente
    cli = v['cliente']
    gasto_cliente[cli] = gasto_cliente.get(cli, 0) + total

    # quantidade por produto
    prod = v['produto']
    quantidade_produto[prod] = quantidade_produto.get(prod, 0) + v['quantidade']

# insights

melhor_cliente = max(gasto_cliente, key=gasto_cliente.get)
produto_mais_vendido = max(quantidade_produto, key=quantidade_produto.get)
melhor_regiao = max(vendas_regiao, key=vendas_regiao.get)
melhor_categoria = max(vendas_categoria, key=vendas_categoria.get)

ranking_clientes = sorted(
    gasto_cliente.items(),
    key=lambda x: x[1],
    reverse=True
)

# resultados
print('='*40)
print('RESULTADOS DA ANÁLISE')
print('='*40)

print('Faturamento total: R$', faturamento_total)
print('Clientes únicos:', len(clientes))
print('Regiões atendidas:', regioes)
print('Produtos vendidos:', len(produtos))

print('\nMelhor cliente:', melhor_cliente)
print('Produto mais vendido:', produto_mais_vendido)
print('Região com maior faturamento:', melhor_regiao)
print('Categoria mais lucrativa:', melhor_categoria)

print('\nRanking de Clientes:')
for nome, valor in ranking_clientes:
    print(f'{nome} -> R$ {valor}')
# Out:
# ======================================================================
# ANÁLISE DE VENDAS - PROJETO DE CIÊNCIA DE DADOS
# ======================================================================
#
# Dataset original: 12 registros
# Dataset limpo: 9 registros
# ========================================
# RESULTADOS DA ANÁLISE
# ========================================
# Faturamento total: R$ 13565
# Clientes únicos: 7
# Regiões atendidas: {'Sul', 'Sudeste', 'Norte'}
# Produtos vendidos: 9
#
# Melhor cliente: João Silva
# Produto mais vendido: Mouse
# Região com maior faturamento: Sudeste
# Categoria mais lucrativa: Eletrônicos
#
# Ranking de Clientes:
# João Silva -> R$ 7660
# Carlos Mendes -> R$ 1700
# Fernanda Rocha -> R$ 1140
# Joao Silva -> R$ 1050
# Ana Lima -> R$ 900
# Pedro Costa -> R$ 890
# Maria Santos -> R$ 225
